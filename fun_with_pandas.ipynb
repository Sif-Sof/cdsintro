# %% [markdown]
# # Lab 03: Fun with `pandas`!

# %% [markdown]
# Below are some exercises to get you working with `pandas` to manipulate data. As always, get as far as you can, and ask for help when you need it! Your teacher (me), you instructor, and your classmates are all here to help each other get better at coding. Getting the code to work is important, but do also take the time to make sure you understand what the commands are doing. This time, (with the exception of the Stroop challenge), all I've given you is the code to download the data. Then you are on your own. For the Stroop challenge, I gave the you code for the first step—after that, it's up to you :-)

# %% [markdown]
# ## Music sales challenge
#
# Write a script that:
#
# 1. Combines the tables of best-selling physical singles and best-selling digital singles on the Wikipedia page "List_of_best-selling_singles" **done**
# 2. Adds a column which marks whether each row is from the list of physical singles or digital singles **done**
# 3. Outputs the artist and single name for the year you were born. If there is no entry for that year, take the closest year after you were born **done**.
# 4. Outputs the artist and single name for the year you were 15 years old. **done**

# %%
# Starter code...

# %pip install lxml

import pandas as pd

rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_best-selling_singles")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 26.9 MB/s eta 0:00:0000:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#list of the physical singles
df_phys=pd.concat(rawdata[0:3])
df_phys.insert(0, 'physical/digital', 'physical')
df_phys
#https://stackoverflow.com/questions/29517072/add-column-to-dataframe-with-constant-value
# Out:
#    physical/digital                   Artist  \
# 0          physical              Bing Crosby
# 1          physical               Elton John
# 2          physical              Bing Crosby
# 3          physical               Tino Rossi
# 4          physical  Bill Haley & His Comets
# ..              ...                      ...
# 65         physical         Blue Öyster Cult
# 66         physical               Billy Joel
# 67         physical                     Chic
# 68         physical            Ozzy Osbourne
# 69         physical                    Queen
#
#                                                Single  Released  \
# 0                                   "White Christmas"      1942
# 1   "Something About the Way You Look Tonight"/"Ca...      1997
# 2                                      "Silent Night"      1935
# 3                                   "Petit Papa Noël"      1946
# 4                             "Rock Around the Clock"      1954
# ...

# %%
#list of the digital single
df_digi=pd.concat(rawdata[4:6])
df_digi.insert(0, 'physical/digital', 'digital')
df_digi
# Out:
#    physical/digital                                    Artist  \
# 0           digital  Robin Thicke featuring T.I. and Pharrell
# 1           digital     Maroon 5 featuring Christina Aguilera
# 2           digital                                     Kesha
# 3           digital                                 Lady Gaga
# 4           digital                         Pharrell Williams
# ..              ...                                       ...
# 16          digital                                 Saint Jhn
# 17          digital                                  Dua Lipa
# 18          digital                            Olivia Rodrigo
# 19          digital                                 Lil Nas X
# 20          digital                    Future featuring Drake
#
#                               Single  Released Sales (in millions) Source  \
# 0                    "Blurred Lines"      2013             14.8[a]   [62]
# ...

# %%
#the combined lists
df_comb=pd.concat([df_phys, df_digi])
df_comb
# Out:
#    physical/digital                   Artist  \
# 0          physical              Bing Crosby
# 1          physical               Elton John
# 2          physical              Bing Crosby
# 3          physical               Tino Rossi
# 4          physical  Bill Haley & His Comets
# ..              ...                      ...
# 16          digital                Saint Jhn
# 17          digital                 Dua Lipa
# 18          digital           Olivia Rodrigo
# 19          digital                Lil Nas X
# 20          digital   Future featuring Drake
#
#                                                Single  Released  \
# 0                                   "White Christmas"      1942
# 1   "Something About the Way You Look Tonight"/"Ca...      1997
# 2                                      "Silent Night"      1935
# 3                                   "Petit Papa Noël"      1946
# 4                             "Rock Around the Clock"      1954
# ...

# %%
#hit singles of my birthyear
birth = df_comb[df_comb['Released']==1998] # Switch the dataframe name and year:) 
birth[['physical/digital','Artist', 'Single']]
# Out:
#    physical/digital          Artist                   Single
# 11         physical            Cher                "Believe"
# 28         physical  Britney Spears  "...Baby One More Time"
# 12         physical   Goo Goo Dolls                   "Iris"
# 19         physical  Britney Spears  "...Baby One More Time"
# 55         physical            Cher                "Believe"

# %%
#my birthyear and the year i turned 15
birth15 = df_comb[df_comb['Released'].isin([1998, 2013])] 
birth15[['physical/digital','Artist', 'Single', 'Released']]
# Out:
#    physical/digital                                    Artist  \
# 11         physical                                      Cher
# 28         physical                            Britney Spears
# 12         physical                             Goo Goo Dolls
# 19         physical                            Britney Spears
# 55         physical                                      Cher
# 0           digital  Robin Thicke featuring T.I. and Pharrell
# 4           digital                         Pharrell Williams
# 9           digital              Katy Perry featuring Juicy J
# 16          digital                               John Legend
# 24          digital               Avicii featuring Aloe Blacc
# 28          digital                              Idina Menzel
# 34          digital                                     Lorde
#
#                      Single  Released
# 11                "Believe"      1998
# 28  "...Baby One More Time"      1998
# 12                   "Iris"      1998
# ...

# %% [markdown]
# ## Space challenge
#
# 1. Make a single dataframe that combines the space missions from the 1950's to the 2020's **done**
# 2. Write a script that returns the year with the most launches **done**
# 3. Write a script that returns the most common month for launches **done**
# 4. Write a script that ranks the months from most launches to fewest launches **done**

# %%
# Starter code...

#%pip install lxml
import pandas as pd

rawdata = pd.read_html("https://en.wikipedia.org/wiki/Timeline_of_Solar_System_exploration")

# %%
df_tss=pd.concat(rawdata[0:8])
df_tss
# Out:
#                                          Mission name       Launch date  \
# 0                                           Sputnik 1    4 October 1957
# 1                                           Sputnik 2   3 November 1957
# 2                                          Explorer 1   1 February 1958
# 3                                          Vanguard 1     17 March 1958
# 4                                              Luna 1    2 January 1959
# ..                                                ...               ...
# 18  Peregrine Mission One (including Iris and Colm...    8 January 2024
# 19  IM-1 Nova-C Odysseus (including EagleCam deplo...  15 February 2024
# 20                                            DRO A/B     13 March 2024
# 21               Queqiao-2 (including Tiandu-1 and 2)     20 March 2024
# 22   Chang'e 6 (including Pakistan's ICUBE-Q cubesat)        3 May 2024
#
#                                           Description         Ref(s)
# ...

# %%
#Write a script that returns the year with the most launches
df_tss[['day', 'month', 'year']] = df_tss['Launch date'].str.split(' ', expand=True)
df_tss.pop('Launch date') #maybe the jury is out
df_tss
# Out:
#                                          Mission name  \
# 0                                           Sputnik 1
# 1                                           Sputnik 2
# 2                                          Explorer 1
# 3                                          Vanguard 1
# 4                                              Luna 1
# ..                                                ...
# 18  Peregrine Mission One (including Iris and Colm...
# 19  IM-1 Nova-C Odysseus (including EagleCam deplo...
# 20                                            DRO A/B
# 21               Queqiao-2 (including Tiandu-1 and 2)
# 22   Chang'e 6 (including Pakistan's ICUBE-Q cubesat)
#
#                                           Description         Ref(s) day  \
# 0                                 First Earth orbiter         [1][2]   4
# 1   Earth orbiter, first animal in orbit, a dog na...      [2][3][4]   3
# 2   Earth orbiter; discovered Van Allen radiation ...            [5]   1
# ...

# %%
#Write a script that returns the year with the most launches
df_year=pd.crosstab(index = df_tss["year"], columns = "count")
df_year.columns =['launches']
df_year=df_year.sort_values(by=['launches'], ascending=False)
df_year.head(1)
# Out:
#       launches
# year
# 1965        12

# %%
#Write a script that returns the most common month for launches
df_month=pd.crosstab(index = df_tss["month"], columns = "count")
df_month.columns =['launches']
df_month=df_month.sort_values(by=['launches'], ascending=False)
df_month.head(1)
# Out:
#           launches
# month
# November        30

# %%
df_month=pd.crosstab(index = df_tss["month"], columns = "count")
df_month.columns =['launches']
df_month=df_month.sort_values(by=['launches'], ascending=False)
df_month
# Out:
#            launches
# month
# November         30
# August           27
# October          22
# September        22
# July             21
# January          19
# December         19
# May              17
# March            15
# February         14
# June             14
# April            13

# %% [markdown]
# ## Supervillain challenge
#
# 1. Write a script that combines the tables showing supervillain debuts from the 30's through the 2010's **done**
# 2. Write a script that ranks each decade in terms of how many supervillains debuted in that decade **done**
# 3. Write a script that ranks the different comics companies in terms of how many supervillains they have, and display the results in a nice table **done**(pandas dataframe)

# %%
rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_comic_book_supervillain_debuts")

# %%
df_sv=pd.concat(rawdata[3:30])
df_sv['Year Debuted']=df_sv['Year Debuted'].str.split(' ').str[0]

decades=['1930s','1940s','1950s','1960s','1970s','1980s','1990s','2000s','2010s']
villains=pd.DataFrame()

for i,decade in enumerate(decades):
    table=rawdata[i+3]
    table['Decade']=decade
    villains=pd.concat([villains, table], ignore_index=True)
df_sv.head()
# Out:
#   Character / Team Year Debuted                   Company  \
# 0   Ultra-Humanite         1939                        DC
# 1        Dr. Death         1939                        DC
# 2         The Monk         1939                        DC
# 3         The Claw         1939  Lev Gleason Publications
# 0         Hath-Set         1940                        DC
#
#                      Creator/s               First Appearance Decade
# 0    Jerry Siegel, Joe Shuster     Action Comics (vol. 1) #13  1930s
# 1        Bob Kane, Bill Finger  Detective Comics (vol. 1) #29  1930s
# 2        Bob Kane, Bill Finger  Detective Comics (vol. 1) #31  1930s
# 3                    Jack Cole        Silver Streak Comics #1  1930s
# 0  Gardner Fox, Dennis Neville                Flash Comics #1  1940s

# %%
df_apperance=pd.crosstab(index = df_sv["Decade"], columns = "count")
df_apperance.columns =['apperances']
df_apperance=df_apperance.sort_values(by=['apperances'], ascending=False)
df_apperance
# Out:
#         apperances
# Decade
# 1960s          228
# 1970s           97
# 1980s           92
# 1990s           84
# 2000s           49
# 1940s           47
# 1950s           26
# 2010s            9
# 1930s            4

# %%
df_company=pd.crosstab(index = df_sv["Company"], columns = "count")
df_company.columns =['apperances']
df_company=df_company.sort_values(by=['apperances'], ascending=False)
df_company
# Out:
#                           apperances
# Company
# DC                               338
# Marvel                           264
# Fawcett Comics/DC                  6
# Dark Horse                         5
# Image                              5
# Disney/Hyperion                    4
# Marvel/Timely                      4
# Eternity                           3
# Comico                             1
# Image Comics                       1
# Lev Gleason Publications           1
# Mirage                             1

# %% [markdown]
# ## Stroop challenge
#
# Every year between 2015 and 2021, the students in my Language, Cognition, and the Brain course participated in a version of the Stroop task. Using a stopwatch (ok, using their phones), they recorded how fast they could say a list of things (either reading or naming colors or color words). The column names mean "Reading with No Interference", "Naming with Interference", "Naming with No Interference", and "Reading with Interference". The times are in seconds.
#
# ### Stroop challenge 1:
# Transform these data from wide format to long format, so that the result is a dataframe with
# - 1 column named "Participant_id" with a unique number for each participant (you can use the row indices) **done**
# - 1 column named "Year" with the year data **done**
# - 1 column named "Task" that shows which task they were doing **done**
# - 1 column named "RT" that shows their response time **done**

# %%
# Starter code 1...

df = pd.read_csv("https://raw.githubusercontent.com/ethanweed/Stroop/master/Stroop-raw-over-the-years.csv")

# %%
# Starter code 2...

# Make a new column using the dataframe indices as particpant numbers

df.index.name = 'Participant_id'
df = df.reset_index()

#df.reset_index(inplace = True)
# NOTE: This line does exactly the same thing as the line above:
# it replaces the original df with a new df with the updated index. That's what
# "inplace = True" means. Or, you can just assign the dataframe with the updated index
# to a new dataframe with the same name as the old dataframe, which is what I did above.
# The end result is the same.
df.head()
# Out:
#    Participant_id  Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  Year
# 0               0           4.16        6.76          4.45         4.65  2015
# 1               1           4.35        7.73          4.78         4.46  2015
# 2               2           3.60        7.00          4.00         3.50  2015
# 3               3           3.90        9.03          4.60         6.30  2015
# 4               4           4.22        9.98          6.83         6.24  2015

# %%
long_df = pd.melt(df,
                  id_vars=['Participant_id','Year'],
                  value_vars=['Reading_NoInt', 'Naming_Int', 'Naming_NoInt', 'Reading_Int'],
                  var_name='Task',
                  value_name='RT'
                 )

long_df
# Out:
#      Participant_id  Year           Task    RT
# 0                 0  2015  Reading_NoInt  4.16
# 1                 1  2015  Reading_NoInt  4.35
# 2                 2  2015  Reading_NoInt  3.60
# 3                 3  2015  Reading_NoInt  3.90
# 4                 4  2015  Reading_NoInt  4.22
# ..              ...   ...            ...   ...
# 723             177  2021    Reading_Int  4.28
# 724             178  2021    Reading_Int  5.49
# 725             179  2021    Reading_Int  5.16
# 726             180  2021    Reading_Int  5.51
# 727             181  2021    Reading_Int  4.59
#
# [728 rows x 4 columns]

# %% [markdown]
# ## Stroop challenge 2 (Advanced!!!):
#
# Make a new dataframe which shows the mean response time (in seconds) for each task for each year.

# %%
#the information i need Task, Year and RT
import statistics
statistics.mean(RT)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[80], line 3
#       1 #the information i need Task, Year and RT
#       2 import statistics
# ----> 3 statistics.mean(RT)
#
# NameError: name 'RT' is not defined
